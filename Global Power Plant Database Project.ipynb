# %%
# Importing the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r'https://raw.githubusercontent.com/wri/global-power-plant-database/master/source_databases_csv/database_IND.csv',index_col=4)
data
# Out:
#             country country_long                          name   gppd_idnr  \
# capacity_mw
# 2.5             IND        India              ACME Solar Tower  WRI1020239
# 98.0            IND        India           ADITYA CEMENT WORKS  WRI1019881
# 39.2            IND        India      AES Saurashtra Windfarms  WRI1026669
# 135.0           IND        India                   AGARTALA GT  IND0000001
# 1800.0          IND        India                  AKALTARA TPP  IND0000002
# ...             ...          ...                           ...         ...
# 1600.0          IND        India                  YERMARUS TPP  IND0000513
# 3.0             IND        India  Yelesandra Solar Power Plant  WRI1026222
# 25.5            IND        India  Yelisirur wind power project  WRI1026776
# 80.0            IND        India                   ZAWAR MINES  WRI1019901
# 16.5            IND        India       iEnergy Theni Wind Farm  WRI1026761
#
# ...

# %%
data.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'latitude', 'longitude',
#        'primary_fuel', 'other_fuel1', 'other_fuel2', 'other_fuel3',
#        'commissioning_year', 'owner', 'source', 'url', 'geolocation_source',
#        'wepp_id', 'year_of_capacity_data', 'generation_gwh_2013',
#        'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016',
#        'generation_gwh_2017', 'generation_gwh_2018', 'generation_gwh_2019',
#        'generation_data_source', 'estimated_generation_gwh'],
#       dtype='object')

# %%
data = data.drop(['country','wepp_id','url','country_long','geolocation_source','name','gppd_idnr', 'latitude','longitude','generation_data_source',],axis = 1)

# %%
data.head()
# Out:
#             primary_fuel other_fuel1 other_fuel2  other_fuel3  \
# capacity_mw
# 2.5                Solar         NaN         NaN          NaN
# 98.0                Coal         NaN         NaN          NaN
# 39.2                Wind         NaN         NaN          NaN
# 135.0                Gas         NaN         NaN          NaN
# 1800.0              Coal         Oil         NaN          NaN
#
#              commissioning_year                 owner  \
# capacity_mw
# 2.5                      2011.0           Solar Paces
# 98.0                        NaN  Ultratech Cement ltd
# 39.2                        NaN                   AES
# 135.0                    2004.0                   NaN
# 1800.0                   2015.0                   NaN
#
#                                            source  year_of_capacity_data  \
# capacity_mw
# 2.5          National Renewable Energy Laboratory                    NaN
# 98.0                         Ultratech Cement ltd                    NaN
# ...

# %%
data['total_generation'] = data['generation_gwh_2013'] + data['generation_gwh_2014'] + data['generation_gwh_2015'] + data['generation_gwh_2016'] + data['generation_gwh_2017'] + data['generation_gwh_2018']+ data['generation_gwh_2019']

# %%
data = data.drop(['generation_gwh_2013','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017','generation_gwh_2018','generation_gwh_2019'],axis = 1)

# %%
data
# Out:
#             primary_fuel other_fuel1 other_fuel2  other_fuel3  \
# capacity_mw
# 2.5                Solar         NaN         NaN          NaN
# 98.0                Coal         NaN         NaN          NaN
# 39.2                Wind         NaN         NaN          NaN
# 135.0                Gas         NaN         NaN          NaN
# 1800.0              Coal         Oil         NaN          NaN
# ...                  ...         ...         ...          ...
# 1600.0              Coal         Oil         NaN          NaN
# 3.0                Solar         NaN         NaN          NaN
# 25.5                Wind         NaN         NaN          NaN
# 80.0                Coal         NaN         NaN          NaN
# 16.5                Wind         NaN         NaN          NaN
#
#              commissioning_year                                owner  \
# capacity_mw
# 2.5                      2011.0                          Solar Paces
# ...
